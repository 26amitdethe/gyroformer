# %%
# %%bash
# cd /content/drive/MyDrive/gyroformer
#
# git add .
# git commit -m "[setup] initialize repo structure"
# git branch -M main
# git push -u origin main
# Out:
# [master (root-commit) 4d9f0a4] [setup] initialize repo structure
#  14 files changed, 12 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 1.ipynb
#  create mode 100644 README.md
#  create mode 100644 configs/.gitkeep
#  create mode 100644 docs/.gitkeep
#  create mode 100644 notebooks/acquisition/.gitkeep
#  create mode 100644 notebooks/eda/.gitkeep
#  create mode 100644 notebooks/preprocessing/.gitkeep
#  create mode 100644 notebooks/scratch/.gitkeep
#  create mode 100644 src/acquisition/.gitkeep
#  create mode 100644 src/evaluation/.gitkeep
#  create mode 100644 src/models/.gitkeep
#  create mode 100644 src/preprocessing/.gitkeep
#  create mode 100644 src/training/.gitkeep
# fatal: could not read Username for 'https://github.com': No such device or address
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ...
